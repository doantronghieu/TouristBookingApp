# %%
import os
import json

# %%
tour_path = os.path.join('data', 'tours.json')
# read json
with open(tour_path) as f:
  tours = json.load(f)

# %%
tours
# Out:
# [{'startLocation': {'description': 'Ha Giang, Vietnam',
#    'type': 'Point',
#    'coordinates': [105.016137, 22.805614],
#    'address': 'Ha Giang Province, Vietnam'},
#   'ratingsAverage': 4.9,
#   'ratingsQuantity': 8,
#   'images': ['ha-giang-tour-1.jpg',
#    'ha-giang-tour-2.jpg',
#    'ha-giang-tour-3.jpg'],
#   'startDates': ['2022-05-15T09:00:00.000Z',
#    '2022-07-20T09:00:00.000Z',
#    '2022-09-10T09:00:00.000Z'],
#   '_id': '5c88fa8cf4afda39709c2955',
#   'name': 'Ha Giang Adventure',
#   'duration': 5,
#   'maxGroupSize': 12,
#   'difficulty': 'medium',
#   'guides': ['5c8a22c62f8fb814b56fa18b', '5c8a1f4e2f8fb814b56fa185'],
#   'price': 599,
#   'summary': 'Discover the stunning landscapes of Ha Giang, Vietnam',
# ...

# %%
descriptions = [tour['startLocation']['description'] for tour in tours]
locations = [description.split(', ')[0] for description in descriptions]
images = [tour['images'] for tour in tours]
images_cover = [tour['imageCover'] for tour in tours]
